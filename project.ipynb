# %% [markdown]
# # Custom Chatbot Project

# %% [markdown]
# TODO: In this cell, write an explanation of which dataset you have chosen and why it is appropriate for this task

# %% [markdown]
# ```As the data in the character_descriptions.csv is a made up data, openai wont be able to provide an adequate response to user queries based on this specific data.```

# %% [markdown]
# ## Data Wrangling
#
# TODO: In the cells below, load your chosen dataset into a `pandas` dataframe with a column named `"text"`. This column should contain all of your text data, separated into at least 20 rows.

# %% [markdown]
# #### Importing the necessary libraries

# %%
import openai
openai.api_base = "https://openai.vocareum.com/v1"
openai.api_key = ""

# %%
import pandas as pd
import numpy as np

# %%
# read the CSV file from the data folder
df = pd.read_csv('data/character_descriptions.csv')
df.head()
# Out:
#     Name                                        Description Medium  Setting
# 0  Emily  A young woman in her early 20s, Emily is an as...   Play  England
# 1   Jack  A middle-aged man in his 40s, Jack is a succes...   Play  England
# 2  Alice  A woman in her late 30s, Alice is a warm and n...   Play  England
# 3    Tom  A man in his 50s, Tom is a retired soldier and...   Play  England
# 4  Sarah  A woman in her mid-20s, Sarah is a free-spirit...   Play  England

# %%
# Check if there are any missing values in the data
df.isnull().sum()
# Out:
# Name           0
# Description    0
# Medium         0
# Setting        0
# dtype: int64

# %%
# check if all the names in the data are unique
df['Name'].nunique() == df.shape[0]
# Out:
# True

# %%
# Normalize all the text in all the columns including the column names
df.columns = df.columns.str.lower()
df = df.apply(lambda x: x.str.lower().str.strip() if x.dtype == "object" else x)
df.head()
# Out:
#     name                                        description medium  setting
# 0  emily  a young woman in her early 20s, emily is an as...   play  england
# 1   jack  a middle-aged man in his 40s, jack is a succes...   play  england
# 2  alice  a woman in her late 30s, alice is a warm and n...   play  england
# 3    tom  a man in his 50s, tom is a retired soldier and...   play  england
# 4  sarah  a woman in her mid-20s, sarah is a free-spirit...   play  england

# %%
# Flatten the dataframe

df['text'] = df.apply(lambda row: f"Actor: {row['name']}\nRole Description: {row['description']}\nMedium: {row['medium']}\nSetting: {row['setting']}", axis=1)

# %%
# drop the columns that are no longer needed
df = df.drop(columns=['name', 'description', 'medium', 'setting'])
df.head()
# Out:
#                                                 text
# 0  Actor: emily\nRole Description: a young woman ...
# 1  Actor: jack\nRole Description: a middle-aged m...
# 2  Actor: alice\nRole Description: a woman in her...
# 3  Actor: tom\nRole Description: a man in his 50s...
# 4  Actor: sarah\nRole Description: a woman in her...

# %% [markdown]
# ## Custom Query Completion
#
# TODO: In the cells below, compose a custom query using your chosen dataset and retrieve results from an OpenAI `Completion` model. You may copy and paste any useful code from the course materials.

# %%
query_prompt_one = """
Question: "What is the name of the teenage daughter of the middle-aged Latina woman who owns a small family-run diner in a small Texas town?"
Answer:
"""
initial_query_answer_one = openai.Completion.create(
    model="gpt-3.5-turbo-instruct",
    prompt=query_prompt_one,
    max_tokens=150
)["choices"][0]["text"].strip()
print(initial_query_answer_one)
# Out:
# The name of the teenage daughter is not provided and can vary.

# %%
query_prompt_two = """
Question: "What is the name of the young woman who Max considers like a second mother?"
Answer:
"""
initial_query_answer_two = openai.Completion.create(
    model="gpt-3.5-turbo-instruct",
    prompt=query_prompt_two,
    max_tokens=150
)["choices"][0]["text"].strip()
print(initial_query_answer_two)
# Out:
# The name of the young woman is Eddie.

# %% [markdown]
# # Generate Embeddings

# %%
EMBEDDING_MODEL_NAME = "text-embedding-ada-002"
batch_size = 10
embeddings = []
for i in range(0, len(df), batch_size):
    # Send text data to OpenAI model to get embeddings
    response = openai.Embedding.create(
        input=df.iloc[i:i+batch_size]["text"].tolist(),
        engine=EMBEDDING_MODEL_NAME
    )
    
    # Add embeddings to list
    embeddings.extend([data["embedding"] for data in response["data"]])

# Add embeddings list to dataframe
df["embeddings"] = embeddings
df
# Out:
#                                                  text  \
# 0   Actor: emily\nRole Description: a young woman ...
# 1   Actor: jack\nRole Description: a middle-aged m...
# 2   Actor: alice\nRole Description: a woman in her...
# 3   Actor: tom\nRole Description: a man in his 50s...
# 4   Actor: sarah\nRole Description: a woman in her...
# 5   Actor: george\nRole Description: a man in his ...
# 6   Actor: rachel\nRole Description: a woman in he...
# 7   Actor: john\nRole Description: a man in his 60...
# 8   Actor: maria\nRole Description: a middle-aged ...
# 9   Actor: caleb\nRole Description: a young africa...
# 10  Actor: tyler\nRole Description: a white man in...
# 11  Actor: sonya\nRole Description: a white woman ...
# 12  Actor: manuel\nRole Description: a middle-aged...
# 13  Actor: will\nRole Description: a white man in ...
# 14  Actor: mia\nRole Description: a young australi...
# 15  Actor: lucas\nRole Description: a middle-aged ...
# 16  Actor: tahlia\nRole Description: a young indig...
# 17  Actor: max\nRole Description: a white australi...
# 18  Actor: ava\nRole Description: a middle-aged au...
# 19  Actor: donna\nRole Description: a seasoned per...
# 20  Actor: johnny\nRole Description: a young up-an...
# 21  Actor: sable\nRole Description: a sultry and d...
# 22  Actor: dolly\nRole Description: a bubbly and v...
# 23  Actor: vixen\nRole Description: a fierce and c...
# 24  Actor: karma\nRole Description: a chameleon-li...
# 25  Actor: crystal\nRole Description: a quirky and...
# 26  Actor: olivia\nRole Description: a confident a...
# 27  Actor: marcus\nRole Description: a charming an...
# 28  Actor: maya\nRole Description: a kind and comp...
# 29  Actor: james\nRole Description: a handsome and...
# 30  Actor: sophia\nRole Description: a fun-loving ...
# 31  Actor: noah\nRole Description: a quirky and cr...
# 32  Actor: chloe\nRole Description: a driven and a...
# 33  Actor: jake\nRole Description: a laid-back and...
# 34  Actor: prince lorenzo\nRole Description: a cha...
# 35  Actor: signora rosa\nRole Description: a myste...
# 36  Actor: baron gustavo\nRole Description: a weal...
# 37  Actor: francesca\nRole Description: a fiery an...
# 38  Actor: don carlo\nRole Description: a charming...
# 39  Actor: duke orsino\nRole Description: a pompou...
# 40  Actor: lady olivia\nRole Description: a wealth...
# 41  Actor: sir toby belch\nRole Description: a dru...
# 42  Actor: malvolio\nRole Description: a pompous a...
# 43  Actor: viola\nRole Description: a plucky and r...
# 44  Actor: sir andrew aguecheek\nRole Description:...
# 45  Actor: bianca\nRole Description: lady olivia's...
# 46  Actor: sebastian\nRole Description: viola's tw...
# 47  Actor: feste\nRole Description: a jester and m...
# 48  Actor: antonio\nRole Description: a sea captai...
# 49  Actor: abigail\nRole Description: a plucky and...
# 50  Actor: thomas\nRole Description: a good-nature...
# 51  Actor: reverend brown\nRole Description: the p...
# 52  Actor: captain james\nRole Description: the ch...
# 53  Actor: mrs. mercer\nRole Description: the matr...
# 54  Actor: mr. mercer\nRole Description: the bumbl...
#
#                                            embeddings
# 0   [-0.017513729631900787, -0.015827419236302376,...
# 1   [0.0034573425073176622, -0.026015250012278557,...
# 2   [0.0008556708344258368, -0.014851642772555351,...
# 3   [0.010522659868001938, -0.0246538408100605, -0...
# 4   [-0.02520163170993328, -0.029377901926636696, ...
# 5   [-0.020184945315122604, -0.017219319939613342,...
# 6   [-0.006879925727844238, -0.01771548204123974, ...
# 7   [0.008729702793061733, -0.02020994946360588, -...
# 8   [-0.015555947087705135, -0.015542348846793175,...
# 9   [0.0028194563928991556, -0.03043750301003456, ...
# 10  [0.007938436232507229, -0.03638394922018051, -...
# 11  [0.00023430812871083617, -0.025631748139858246...
# 12  [-0.01788993552327156, -0.02293337509036064, -...
# 13  [-0.009753977879881859, -0.03488609567284584, ...
# 14  [-0.012495279312133789, -0.021629804745316505,...
# 15  [0.0015686164842918515, -0.01754605956375599, ...
# 16  [-0.014769287779927254, -0.008230112493038177,...
# 17  [-0.00013563783431891352, -0.04051500931382179...
# 18  [0.0014568554470315576, -0.013765241950750351,...
# 19  [-0.024389352649450302, -0.012637995183467865,...
# 20  [-0.02860119938850403, -0.022719714790582657, ...
# 21  [-0.025077439844608307, -0.015759862959384918,...
# 22  [-0.03623223304748535, -0.017781870439648628, ...
# 23  [-0.03619479387998581, -0.016779493540525436, ...
# 24  [-0.003497079247608781, -0.01827806793153286, ...
# 25  [-0.012370952405035496, -0.0204802043735981, -...
# 26  [-0.007688071113079786, -0.020169569179415703,...
# 27  [-0.012601876631379128, -0.04327016323804855, ...
# 28  [-0.022137047722935677, -0.026917563751339912,...
# 29  [-0.020662786439061165, -0.019555144011974335,...
# 30  [0.012436616234481335, -0.011862722225487232, ...
# 31  [-0.021063916385173798, -0.015714561566710472,...
# 32  [-0.0036574089899659157, -0.01070230733603239,...
# 33  [-0.016708293929696083, -0.025003653019666672,...
# 34  [-0.008429731242358685, -0.020367488265037537,...
# 35  [-6.920635496499017e-05, -0.012826722115278244...
# 36  [-0.025830205529928207, -0.01610901765525341, ...
# 37  [-0.015987416729331017, -0.02097358927130699, ...
# 38  [-0.013078207150101662, -0.015047977678477764,...
# 39  [-0.014126074500381947, -0.0390726700425148, -...
# 40  [-0.01980997435748577, -0.028731022030115128, ...
# 41  [-0.006466724444180727, -0.03783516213297844, ...
# 42  [-0.017006952315568924, -0.033987537026405334,...
# 43  [-0.012699402868747711, -0.037693604826927185,...
# 44  [-0.021517429500818253, -0.022459404543042183,...
# 45  [-0.013264982961118221, -0.027639783918857574,...
# 46  [-0.015560916624963284, -0.04448195546865463, ...
# 47  [-0.010735036805272102, -0.02070087566971779, ...
# 48  [-0.015794966369867325, -0.03670321777462959, ...
# 49  [-0.024748265743255615, -0.023868681862950325,...
# 50  [-0.01752825640141964, -0.015735892578959465, ...
# 51  [-0.0035652401857078075, -0.029308371245861053...
# 52  [-0.005772268399596214, -0.022340312600135803,...
# 53  [-0.020833570510149002, -0.015848441049456596,...
# 54  [0.001644813222810626, -0.011753101833164692, ...

# %%
# Save the dataframe to a CSV file
df.to_csv('data/character_descriptions_embeddings.csv', index=False)

# %% [markdown]
# # Retrieve related documens for a given query

# %%
df = pd.read_csv("data/character_descriptions_embeddings.csv")
# Convert the embeddings column from numpy array to list
df["embeddings"] = df["embeddings"].apply(lambda x: np.array(eval(x)).tolist())
df.head()
# Out:
#                                                 text  \
# 0  Actor: emily\nRole Description: a young woman ...
# 1  Actor: jack\nRole Description: a middle-aged m...
# 2  Actor: alice\nRole Description: a woman in her...
# 3  Actor: tom\nRole Description: a man in his 50s...
# 4  Actor: sarah\nRole Description: a woman in her...
#
#                                           embeddings
# 0  [-0.017513729631900787, -0.015827419236302376,...
# 1  [0.0034573425073176622, -0.026015250012278557,...
# 2  [0.0008556708344258368, -0.014851642772555351,...
# 3  [0.010522659868001938, -0.0246538408100605, -0...
# 4  [-0.02520163170993328, -0.029377901926636696, ...

# %%
from openai.embeddings_utils import get_embedding, distances_from_embeddings

def get_rows_sorted_by_relevance(question, df):
    """
    Function that takes in a question string and a dataframe containing
    rows of text and associated embeddings, and returns that dataframe
    sorted from least to most relevant for that question
    """
    
    # Get embeddings for the question text
    question_embeddings = get_embedding(question, engine=EMBEDDING_MODEL_NAME)
    df_copy = df.copy()
    df_embeddings = df_copy["embeddings"].values
    
    # Make a copy of the dataframe and add a "distances" column containing
    # the cosine distances between each row's embeddings and the
    # embeddings of the question
    df_copy = df.copy()
    distances = distances_from_embeddings(
        question_embeddings,
        df_embeddings,
        distance_metric="cosine"
    )
    df_copy["distances"] = distances
     
    # Sort the copied dataframe by the distances and return it
    # (shorter distance = more relevant so we sort in ascending order)
    df_copy.sort_values("distances", ascending=True, inplace=True)
    return df_copy

# %%
get_rows_sorted_by_relevance("What is the name of the teenage daughter of the middle-aged Latina woman who owns a small family-run diner in a small Texas town?", df)
# Out:
#                                                  text  \
# 8   Actor: maria\nRole Description: a middle-aged ...
# 11  Actor: sonya\nRole Description: a white woman ...
# 12  Actor: manuel\nRole Description: a middle-aged...
# 0   Actor: emily\nRole Description: a young woman ...
# 20  Actor: johnny\nRole Description: a young up-an...
# 49  Actor: abigail\nRole Description: a plucky and...
# 13  Actor: will\nRole Description: a white man in ...
# 16  Actor: tahlia\nRole Description: a young indig...
# 14  Actor: mia\nRole Description: a young australi...
# 10  Actor: tyler\nRole Description: a white man in...
# 6   Actor: rachel\nRole Description: a woman in he...
# 2   Actor: alice\nRole Description: a woman in her...
# 37  Actor: francesca\nRole Description: a fiery an...
# 9   Actor: caleb\nRole Description: a young africa...
# 4   Actor: sarah\nRole Description: a woman in her...
# 19  Actor: donna\nRole Description: a seasoned per...
# 18  Actor: ava\nRole Description: a middle-aged au...
# 50  Actor: thomas\nRole Description: a good-nature...
# 30  Actor: sophia\nRole Description: a fun-loving ...
# 35  Actor: signora rosa\nRole Description: a myste...
# 26  Actor: olivia\nRole Description: a confident a...
# 1   Actor: jack\nRole Description: a middle-aged m...
# 32  Actor: chloe\nRole Description: a driven and a...
# 3   Actor: tom\nRole Description: a man in his 50s...
# 22  Actor: dolly\nRole Description: a bubbly and v...
# 21  Actor: sable\nRole Description: a sultry and d...
# 28  Actor: maya\nRole Description: a kind and comp...
# 15  Actor: lucas\nRole Description: a middle-aged ...
# 40  Actor: lady olivia\nRole Description: a wealth...
# 53  Actor: mrs. mercer\nRole Description: the matr...
# 38  Actor: don carlo\nRole Description: a charming...
# 45  Actor: bianca\nRole Description: lady olivia's...
# 24  Actor: karma\nRole Description: a chameleon-li...
# 5   Actor: george\nRole Description: a man in his ...
# 25  Actor: crystal\nRole Description: a quirky and...
# 52  Actor: captain james\nRole Description: the ch...
# 54  Actor: mr. mercer\nRole Description: the bumbl...
# 27  Actor: marcus\nRole Description: a charming an...
# 7   Actor: john\nRole Description: a man in his 60...
# 34  Actor: prince lorenzo\nRole Description: a cha...
# 43  Actor: viola\nRole Description: a plucky and r...
# 23  Actor: vixen\nRole Description: a fierce and c...
# 33  Actor: jake\nRole Description: a laid-back and...
# 17  Actor: max\nRole Description: a white australi...
# 29  Actor: james\nRole Description: a handsome and...
# 36  Actor: baron gustavo\nRole Description: a weal...
# 51  Actor: reverend brown\nRole Description: the p...
# 46  Actor: sebastian\nRole Description: viola's tw...
# 48  Actor: antonio\nRole Description: a sea captai...
# 47  Actor: feste\nRole Description: a jester and m...
# 29  [-0.020662786439061165, -0.019555144011974335,...   0.282309
# 36  [-0.025830205529928207, -0.01610901765525341, ...   0.282473
# 51  [-0.0035652401857078075, -0.029308371245861053...   0.285835
# 46  [-0.015560916624963284, -0.04448195546865463, ...   0.286437
# 48  [-0.015794966369867325, -0.03670321777462959, ...   0.287599
# 47  [-0.010735036805272102, -0.02070087566971779, ...   0.289041
# 31  [-0.021063916385173798, -0.015714561566710472,...   0.293005
# 42  [-0.017006952315568924, -0.033987537026405334,...   0.293753
# 39  [-0.014126074500381947, -0.0390726700425148, -...   0.298630
# 44  [-0.021517429500818253, -0.022459404543042183,...   0.299645
# 41  [-0.006466724444180727, -0.03783516213297844, ...   0.301684

# %%
get_rows_sorted_by_relevance("What is the name of the young woman who Max considers like a second mother?", df)
# Out:
#                                                  text  \
# 14  Actor: mia\nRole Description: a young australi...
# 17  Actor: max\nRole Description: a white australi...
# 16  Actor: tahlia\nRole Description: a young indig...
# 2   Actor: alice\nRole Description: a woman in her...
# 8   Actor: maria\nRole Description: a middle-aged ...
# 0   Actor: emily\nRole Description: a young woman ...
# 6   Actor: rachel\nRole Description: a woman in he...
# 4   Actor: sarah\nRole Description: a woman in her...
# 11  Actor: sonya\nRole Description: a white woman ...
# 28  Actor: maya\nRole Description: a kind and comp...
# 1   Actor: jack\nRole Description: a middle-aged m...
# 20  Actor: johnny\nRole Description: a young up-an...
# 18  Actor: ava\nRole Description: a middle-aged au...
# 35  Actor: signora rosa\nRole Description: a myste...
# 53  Actor: mrs. mercer\nRole Description: the matr...
# 32  Actor: chloe\nRole Description: a driven and a...
# 40  Actor: lady olivia\nRole Description: a wealth...
# 37  Actor: francesca\nRole Description: a fiery an...
# 3   Actor: tom\nRole Description: a man in his 50s...
# 26  Actor: olivia\nRole Description: a confident a...
# 45  Actor: bianca\nRole Description: lady olivia's...
# 5   Actor: george\nRole Description: a man in his ...
# 49  Actor: abigail\nRole Description: a plucky and...
# 30  Actor: sophia\nRole Description: a fun-loving ...
# 7   Actor: john\nRole Description: a man in his 60...
# 50  Actor: thomas\nRole Description: a good-nature...
# 22  Actor: dolly\nRole Description: a bubbly and v...
# 52  Actor: captain james\nRole Description: the ch...
# 24  Actor: karma\nRole Description: a chameleon-li...
# 19  Actor: donna\nRole Description: a seasoned per...
# 15  Actor: lucas\nRole Description: a middle-aged ...
# 43  Actor: viola\nRole Description: a plucky and r...
# 13  Actor: will\nRole Description: a white man in ...
# 21  Actor: sable\nRole Description: a sultry and d...
# 54  Actor: mr. mercer\nRole Description: the bumbl...
# 12  Actor: manuel\nRole Description: a middle-aged...
# 23  Actor: vixen\nRole Description: a fierce and c...
# 51  Actor: reverend brown\nRole Description: the p...
# 25  Actor: crystal\nRole Description: a quirky and...
# 10  Actor: tyler\nRole Description: a white man in...
# 46  Actor: sebastian\nRole Description: viola's tw...
# 38  Actor: don carlo\nRole Description: a charming...
# 47  Actor: feste\nRole Description: a jester and m...
# 33  Actor: jake\nRole Description: a laid-back and...
# 27  Actor: marcus\nRole Description: a charming an...
# 29  Actor: james\nRole Description: a handsome and...
# 9   Actor: caleb\nRole Description: a young africa...
# 34  Actor: prince lorenzo\nRole Description: a cha...
# 33  [-0.016708293929696083, -0.025003653019666672,...   0.277838
# 27  [-0.012601876631379128, -0.04327016323804855, ...   0.277998
# 29  [-0.020662786439061165, -0.019555144011974335,...   0.279209
# 9   [0.0028194563928991556, -0.03043750301003456, ...   0.280892
# 34  [-0.008429731242358685, -0.020367488265037537,...   0.281986
# 42  [-0.017006952315568924, -0.033987537026405334,...   0.285476
# 36  [-0.025830205529928207, -0.01610901765525341, ...   0.287354
# 48  [-0.015794966369867325, -0.03670321777462959, ...   0.289582
# 31  [-0.021063916385173798, -0.015714561566710472,...   0.291101
# 44  [-0.021517429500818253, -0.022459404543042183,...   0.291181
# 41  [-0.006466724444180727, -0.03783516213297844, ...   0.291576
# 39  [-0.014126074500381947, -0.0390726700425148, -...   0.292220

# %% [markdown]
# # Compose a text prompt

# %%
import tiktoken

def create_prompt(question, df, max_token_count):
    """
    Given a question and a dataframe containing rows of text and their
    embeddings, return a text prompt to send to a Completion model
    """
    # Create a tokenizer that is designed to align with our embeddings
    tokenizer = tiktoken.get_encoding("cl100k_base")
    
    # Count the number of tokens in the prompt template and question
    prompt_template = """
        Answer the question based on the context below, and if the question
        can't be answered based on the context, say "I don't know"

        Context: 

        {}

        ---

        Question: {}
        Answer:"""
    
    current_token_count = len(tokenizer.encode(prompt_template)) + \
                            len(tokenizer.encode(question))
    
    context = []
    for text in get_rows_sorted_by_relevance(question, df)["text"].values:
        
        # Increase the counter based on the number of tokens in this row
        text_token_count = len(tokenizer.encode(text))
        current_token_count += text_token_count
        
        # Add the row of text to the list if we haven't exceeded the max
        if current_token_count <= max_token_count:
            context.append(text)
        else:
            break

    return prompt_template.format("\n\n###\n\n".join(context), question)

# %%
print(create_prompt("What is the name of the teenage daughter of the middle-aged Latina woman who owns a small family-run diner in a small Texas town?", df, 200))
# Out:
#         Answer the question based on the context below, and if the question
#         can't be answered based on the context, say "I don't know"
#
#         Context:
#
#         Actor: maria
# Role Description: a middle-aged latina woman in her 40s, maria is a hard-working single mother who owns a small family-run diner in a small texas town. she's fiercely protective of her teenage daughter, sofia, and is always trying to balance work and family.
# Medium: movie
# Setting: texas
#
#         ---
#
#         Question: What is the name of the teenage daughter of the middle-aged Latina woman who owns a small family-run diner in a small Texas town?
#         Answer:

# %%
print(create_prompt("What is the name of the young woman who Max considers like a second mother?", df, 200))
# Out:
#         Answer the question based on the context below, and if the question
#         can't be answered based on the context, say "I don't know"
#
#         Context:
#
#         Actor: mia
# Role Description: a young australian woman in her mid-20s, mia is a driven and ambitious lawyer who's just landed her dream job at a top law firm in sydney. she's the younger sister of max, a former soldier who's struggling with ptsd, and is trying to help him navigate his challenges while also balancing her demanding career.
# Medium: limited series
# Setting: australia
#
#         ---
#
#         Question: What is the name of the young woman who Max considers like a second mother?
#         Answer:

# %% [markdown]
# # Answer the Question

# %%
COMPLETION_MODEL_NAME = "gpt-3.5-turbo-instruct"

def answer_question(
    question, df, max_prompt_tokens=1800, max_answer_tokens=150
):
    """
    Given a question, a dataframe containing rows of text, and a maximum
    number of desired tokens in the prompt and response, return the
    answer to the question according to an OpenAI Completion model
    
    If the model produces an error, return an empty string
    """
    
    prompt = create_prompt(question, df, max_prompt_tokens)
    
    try:
        response = openai.Completion.create(
            model=COMPLETION_MODEL_NAME,
            prompt=prompt,
            max_tokens=max_answer_tokens
        )
        return response["choices"][0]["text"].strip()
    except Exception as e:
        print(e)
        return ""

# %%
custom_query_answer_one = answer_question("What is the name of the teenage daughter of the middle-aged Latina woman who owns a small family-run diner in a small Texas town?", df)
print(custom_query_answer_one)
# Out:
# Sofia

# %%
custom_query_answer_two = answer_question("What is the name of the young woman who Max considers like a second mother?", df)
print(custom_twitter_answer)
# Out:
# Ava

# %% [markdown]
# ## Custom Performance Demonstration
#
# TODO: In the cells below, demonstrate the performance of your custom query using at least 2 questions. For each question, show the answer from a basic `Completion` model query as well as the answer from your custom query.

# %% [markdown]
# ### Question 1

# %%
print(f"""
"What is the name of the teenage daughter of the middle-aged Latina woman who owns a small family-run diner in a small Texas town?"

Original Answer: {initial_query_answer_one}
Custom Answer:   {custom_query_answer_one}

""")
# Out:
# "What is the name of the teenage daughter of the middle-aged Latina woman who owns a small family-run diner in a small Texas town?"
#
# Original Answer: The name of the teenage daughter is not provided and can vary.
# Custom Answer:   Sofia

# %% [markdown]
# ### Question 2

# %%
print(f"""
"What is the name of the young woman who Max considers like a second mother?"
      
Original Answer: {initial_query_answer_two}
Custom Answer:   {custom_query_answer_two}
""")
# Out:
# "What is the name of the young woman who Max considers like a second mother?"
#
# Original Answer: The name of the young woman is Eddie.
# Custom Answer:   Ava
